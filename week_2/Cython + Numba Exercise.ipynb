# %% [markdown]
# Exercise is meant for you to experiment with cython and numba to see how much efficiency can be obtained by using these two tools

# %%
import numpy as np
import seaborn as sb
import pandas as pd

# %%
class Particle:
  def __init__(self, x, y, ang_speed):
    self.x = x
    self.y = y
    self.ang_speed = ang_speed

# %%
def evolve_wrapper(dt, particles):
  timestep = 1
  nsteps = int(dt/timestep)
  r_i = np.array([[p.x, p.y] for p in particles])
  ang_speed = np.array([p.ang_speed for p in particles])
  evolve(r_i, ang_speed, timestep, nsteps)

  for i, p in enumerate(particles):
    p.x, p.y = r_i[i]

def evolve(r_i, ang_speed, timestep, nsteps):
  v_i = np.empty_like(r_i)
  for i in range(nsteps):
    norm_i = np.sqrt((r_i ** 2).sum(axis=1))
    v_i = r_i[:, [1,0]]
    v_i[:, 0] *= -1
    v_i /= norm_i[:, np.newaxis]
    d_i = timestep * ang_speed[:, np.newaxis] * v_i

    r_i += d_i

# %%
n_particle = 100
coord = np.random.randn(n_particle, 3)
particles = []
for i in range(0, n_particle):
  particles.append(Particle(coord[i][0], coord[i][1], coord[i][2]))

# %%
sb.scatterplot(x='x', y='y', data=pd.DataFrame([[p.x,p.y] for p in particles],columns = ['x', 'y']))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
evolve_wrapper(1, particles)

# %%
sb.scatterplot(x='x', y='y', data=pd.DataFrame([[p.x,p.y] for p in particles],columns = ['x', 'y']))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
# %timeit evolve_wrapper(1, particles)
# Out:
# 138 µs ± 2.08 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# Can you rewrite the evolve method to make it faster?

# %% [markdown]
# - Cython

# %%
import cython
# %load_ext Cython

# %%
# %%cython
#
# cimport numpy as c_np
# import numpy as np
# from libc cimport math
#
# cdef c_evolve(double[:,:] r_i, double[:] ang_speed, double timestep, int nsteps):
#     cdef int i, j
#     cdef int n = r_i.shape[0]
#     cdef double x, y, norm, vx, vy, dx, dy
#     for i in range(nsteps):
#         for j in range(n):
#             x, y = r_i[j, 0], r_i[j, 1]
#             norm = math.sqrt(x**2 + y**2)
#             vx, vy = -y/norm, x/norm
#             r_i[j, 0] += timestep * ang_speed[j] * vx
#             r_i[j, 1] += timestep * ang_speed[j] * vy
#
# def c_evolve_wrapper(dt, particles):
#   timestep = 1
#   nsteps = int(dt/timestep)
#   r_i = np.array([[p.x, p.y] for p in particles])
#   ang_speed = np.array([p.ang_speed for p in particles])
#   c_evolve(r_i, ang_speed, timestep, nsteps)
#
#   for i, p in enumerate(particles):
#     p.x, p.y = r_i[i]

# %%
c_evolve_wrapper(1, particles)
sb.scatterplot(x='x', y='y', data=pd.DataFrame([[p.x,p.y] for p in particles],columns = ['x', 'y']))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
# %timeit c_evolve_wrapper(1, particles)
# Out:
# 114 µs ± 10.5 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# - numba

# %%
import numba as nb
from numba import jit

# %%
def nb_evolve_wrapper(dt, particles):
  timestep = 1
  nsteps = int(dt/timestep)
  r_i = np.array([[p.x, p.y] for p in particles])
  ang_speed = np.array([p.ang_speed for p in particles])
  nb_evolve(r_i, ang_speed, timestep, nsteps)

  for i, p in enumerate(particles):
    p.x, p.y = r_i[i]

@jit(nopython=True)
def nb_evolve(r_i, ang_speed, timestep, nsteps):
  v_i = np.empty_like(r_i)
  for i in range(nsteps):
    norm_i = np.sqrt((r_i ** 2).sum(axis=1))
    v_i[:, 0] = -r_i[:, 0] / norm_i
    v_i[:, 1] = r_i[:, 1] / norm_i
    d_i = np.empty_like(r_i)
    d_i[:, 0] = timestep * ang_speed * v_i[:, 0]
    d_i[:, 1] = timestep * ang_speed * v_i[:, 1]

    r_i += d_i

# %%
nb_evolve_wrapper(1, particles)
sb.scatterplot(x='x', y='y', data=pd.DataFrame([[p.x,p.y] for p in particles],columns = ['x', 'y']))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
# %timeit nb_evolve_wrapper(1, particles)
# Out:
# 118 µs ± 106 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
